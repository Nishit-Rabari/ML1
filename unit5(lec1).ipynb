# %% [markdown]
# #

# %% [markdown]
# K NN:   ("K Neighbor classifiar")
#
# or
#
# k-Nearest Neighbors

# %% [markdown]
# d=root[(x2-x1)^2 +(y2-y1)^2]

# %%
# pridicted    actual
# w            w         tp
# w            l         fp
# l            w         fn
# l            l         tn
# w            l         fp
# l            w         fn
# w            w         tp
# l            l         tn
# w            w         tp




# tp=3
# tn=2
# fp=2
# fn=2

# %%
# actual          predicted
#                  no    yes
 
# a                tn     fp
# c   no           tn     fp
# t

# u                fn     tp
# a   yes          fn     tp
# l



# cm=[[tn,fp],[fn,tp]]
# tm=cm[0][0]
# tp=cm[2][2]

# %%
# Accuracy= (tp+tn)/(tp+tn+fp+fn)
# Error_rate= (fp+fn)/(tp+tn+fp+fn)   or  1-Accuracy
# sensitivity= (tp)/(tp+fn)  
# speciticity= (tn)/(tn+fp)
